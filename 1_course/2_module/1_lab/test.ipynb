# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

print(torch.cuda.is_available(), torch.mps.is_available()) # False, True
# Out:
# False True
